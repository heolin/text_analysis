# %% [markdown]
# Based on http://scikit-learn.org/stable/auto_examples/text/document_clustering.html

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn import metrics
from sklearn.cluster import KMeans

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import numpy as np

# %%
class DocumentClustering(object):
    def __init__(self, dataset, target):
        self.dataset = dataset
        self.labels = target
        self.labels_count = np.unique(self.labels).shape[0]
        
        self.vectorizer = TfidfVectorizer(stop_words='english')
        
        self._vectorize_data()
        
        
    def _vectorize_data(self):
        self.X = self.vectorizer.fit_transform(self.dataset)
        
    def train(self, verbose=False):
        self.kmeans = KMeans(n_clusters=self.labels_count, verbose=verbose)
        self.kmeans.fit(self.X)
        
    def print_metrics(self):
        print "Homogeneity: %0.3f" % metrics.homogeneity_score(self.labels, self.kmeans.labels_)
        print "Completeness: %0.3f" % metrics.completeness_score(self.labels, self.kmeans.labels_)
        print "V-measure: %0.3f" % metrics.v_measure_score(self.labels, self.kmeans.labels_)
        print "Adjusted Rand-Index: %.3f" % metrics.adjusted_rand_score(labels, self.kmeans.labels_)
        print "Silhouette Coefficient: %0.3f" % metrics.silhouette_score(self.X, self.kmeans.labels_, sample_size=1000)

# %%
input_categories = ['talk.politics.misc', 'soc.religion.christian', 'comp.graphics', 'sci.med']
train_dataset = fetch_20newsgroups(subset='train', categories=input_categories, shuffle=True, random_state=42)

# %%
dc = DocumentClustering(train_dataset.data, train_dataset.target)
dc.train(True)
# Out:
# Initialization complete
# Iteration  0, inertia 4312.431
# Iteration  1, inertia 2192.360
# Iteration  2, inertia 2186.371
# Iteration  3, inertia 2182.036
# Iteration  4, inertia 2179.941
# Iteration  5, inertia 2177.540
# Iteration  6, inertia 2174.825
# Iteration  7, inertia 2172.900
# Iteration  8, inertia 2171.067
# Iteration  9, inertia 2169.904
# Iteration 10, inertia 2169.409
# Iteration 11, inertia 2168.967
# Iteration 12, inertia 2168.684
# Iteration 13, inertia 2168.518
# Iteration 14, inertia 2168.081
# Iteration 15, inertia 2166.293
# Iteration 16, inertia 2165.028
# Iteration 17, inertia 2164.953
# Converged at iteration 17: center shift 0.000000e+00 within tolerance 2.674971e-09
# Initialization complete
# Iteration  0, inertia 4312.468
# Iteration  1, inertia 2188.359
# Iteration  2, inertia 2179.758
# Iteration  3, inertia 2174.284
# Iteration  4, inertia 2170.210
# Iteration  5, inertia 2167.740
# Iteration  6, inertia 2166.061
# Iteration  7, inertia 2165.569
# Iteration  8, inertia 2165.423
# Iteration  9, inertia 2165.382
# Iteration 10, inertia 2165.362
# Converged at iteration 10: center shift 0.000000e+00 within tolerance 2.674971e-09
# Initialization complete
# Iteration  0, inertia 4309.061
# Iteration  1, inertia 2191.333
# Iteration  2, inertia 2184.015
# Iteration  3, inertia 2180.344
# Iteration  4, inertia 2177.666
# Iteration  5, inertia 2175.427
# Iteration  6, inertia 2173.041
# Iteration  7, inertia 2171.360
# Iteration  8, inertia 2171.039
# Iteration  9, inertia 2170.869
# Iteration 10, inertia 2170.789
# Iteration 11, inertia 2170.734
# Iteration 12, inertia 2170.670
# Iteration 13, inertia 2170.624
# Iteration 14, inertia 2170.591
# Iteration 15, inertia 2170.568
# Iteration 16, inertia 2170.544
# Iteration 17, inertia 2170.532
# Iteration 18, inertia 2170.529
# Iteration 19, inertia 2170.526
# Converged at iteration 19: center shift 0.000000e+00 within tolerance 2.674971e-09
# Initialization complete
# Iteration  0, inertia 4275.972
# Iteration  1, inertia 2190.269
# Iteration  2, inertia 2183.800
# Iteration  3, inertia 2180.543
# Iteration  4, inertia 2178.683
# Iteration  5, inertia 2177.555
# Iteration  6, inertia 2177.078
# Iteration  7, inertia 2176.759
# Iteration  8, inertia 2176.525
# Iteration  9, inertia 2176.321
# Iteration 10, inertia 2175.848
# Iteration 11, inertia 2175.381
# Iteration 12, inertia 2174.855
# Iteration 13, inertia 2174.542
# Iteration 14, inertia 2174.354
# Iteration 15, inertia 2174.259
# Iteration 16, inertia 2174.203
# Iteration 17, inertia 2174.156
# Iteration 18, inertia 2174.096
# Iteration 19, inertia 2174.068
# Iteration 20, inertia 2174.045
# Iteration 21, inertia 2174.027
# Iteration 22, inertia 2174.013
# Iteration 23, inertia 2173.999
# Iteration 24, inertia 2173.989
# Iteration 25, inertia 2173.986
# Iteration 26, inertia 2173.981
# Iteration 27, inertia 2173.976
# Iteration 28, inertia 2173.968
# Iteration 29, inertia 2173.966
# Converged at iteration 29: center shift 0.000000e+00 within tolerance 2.674971e-09
# Initialization complete
# Iteration  0, inertia 4315.242
# Iteration  1, inertia 2191.282
# Iteration  2, inertia 2183.375
# Iteration  3, inertia 2178.518
# Iteration  4, inertia 2173.921
# Iteration  5, inertia 2169.519
# Iteration  6, inertia 2167.300
# Iteration  7, inertia 2166.647
# Iteration  8, inertia 2166.443
# Iteration  9, inertia 2166.363
# Iteration 10, inertia 2166.327
# Iteration 11, inertia 2166.303
# Converged at iteration 11: center shift 0.000000e+00 within tolerance 2.674971e-09
# Initialization complete
# Iteration  0, inertia 4302.545
# Iteration  1, inertia 2186.881
# Iteration  2, inertia 2181.090
# Iteration  3, inertia 2175.844
# Iteration  4, inertia 2169.886
# Iteration  5, inertia 2166.937
# Iteration  6, inertia 2166.304
# Iteration  7, inertia 2166.089
# Iteration  8, inertia 2165.953
# Iteration  9, inertia 2165.889
# Iteration 10, inertia 2165.826
# Iteration 11, inertia 2165.799
# Iteration 12, inertia 2165.760
# Iteration 13, inertia 2165.734
# Iteration 14, inertia 2165.710
# Iteration 15, inertia 2165.693
# Iteration 16, inertia 2165.684
# Iteration 17, inertia 2165.679
# Iteration 18, inertia 2165.676
# Iteration 19, inertia 2165.670
# Iteration 20, inertia 2165.667
# Iteration 21, inertia 2165.664
# Converged at iteration 21: center shift 0.000000e+00 within tolerance 2.674971e-09

# %%
dc.print_metrics()
# Out:
# Homogeneity: 0.316
# Completeness: 0.509
# V-measure: 0.390
# Adjusted Rand-Index: 0.183
# Silhouette Coefficient: 0.007

# %%
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = count_vect.get_feature_names()
for i in range(len(categories)):
    print "Cluster %d:" % i
    for ind in order_centroids[i, :10]:
        print ' %s' % terms[ind] 
    print
# Out:
# Cluster 0:
#  edu
#  com
#  cramer
#  optilink
#  people
#  government
#  article
#  writes
#  state
#  clinton
#
# Cluster 1:
#  edu
#  com
#  subject
#  lines
#  organization
#  graphics
#  university
#  posting
#  host
#  nntp
#
# Cluster 2:
#  god
#  jesus
#  edu
#  christians
#  christian
#  people
#  christ
#  church
#  bible
#  faith
#
# Cluster 3:
#  pitt
#  geb
#  banks
#  gordon
#  cs
#  edu
#  cadre
#  dsl
#  shameful
#  n3jxp
